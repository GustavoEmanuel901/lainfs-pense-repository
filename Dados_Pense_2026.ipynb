# %% [markdown]
# <a href="https://colab.research.google.com/github/GustavoEmanuel901/lainfs-pense-repository/blob/Gustavo/Dados_Pense_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('PENSE2019_MICRODADOS.csv')

# %%
linhas_com_menos2 = (df == -2).any(axis=1)

total_linhas = linhas_com_menos2.sum()

print("Número de linhas com pelo menos um -2 (Abandono de formulário)", total_linhas)
# Out:
# Número de linhas com pelo menos um -2 (Abandono de formulário) 843

# %%
def column_replace(df, column_name, old_value, new_value):
    df[column_name] = df[column_name].replace(old_value, new_value)

# %%
def normaliza_coluna(df, column_name):
  df[column_name] = df[column_name] - df[column_name].min()

# %%
# Remover linhas que contenham -2 em qualquer coluna
print("Linhas antes:", len(df))

df = df[~(df == -2).any(axis=1)]

print("Linhas depois:", len(df))
# Out:
# Linhas antes: 165838
# Linhas depois: 164995

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 164995 entries, 0 to 165837
# Columns: 306 entries, REGIAO to TOTAIS_POSEST
# dtypes: float64(296), int64(9), object(1)
# memory usage: 386.5+ MB

# %% [markdown]
# # Informações gerais

# %% [markdown]
# ## Qual é o seu sexo? ![image.png](data:image/png;base64,...)

# %%
df['B01001A'].value_counts(normalize=True)
# Out:
# B01001A
# 2.0    0.508548
# 1.0    0.488655
# 9.0    0.002797
# Name: proportion, dtype: float64

# %%
column_replace(df, 'B01001A', 9, np.nan)

normaliza_coluna(df, 'B01001A')

df['B01001A'].value_counts(normalize=True)
# Out:
# B01001A
# 1.0    0.509974
# 0.0    0.490026
# Name: proportion, dtype: float64

# %% [markdown]
# ## Qual é a sua idade? ![image.png](data:image/png;base64,...)

# %%
df['B01003'].value_counts(normalize=True)
# Out:
# B01003
# 2.0    0.517367
# 3.0    0.267112
# 1.0    0.161273
# 4.0    0.051559
# 9.0    0.002689
# Name: proportion, dtype: float64

# %%
column_replace(df, 'B01003', 9, np.nan)

normaliza_coluna(df, 'B01003')

df['B01003'].value_counts(normalize=True)
# Out:
# B01003
# 1.0    0.518762
# 2.0    0.267832
# 0.0    0.161708
# 3.0    0.051698
# Name: proportion, dtype: float64

# %%
del df['B01004']
del df['B01005']

# %% [markdown]
# ## Qual é a sua cor ou raça? ![image.png](data:image/png;base64,...)

# %%
df['B01002'].value_counts(normalize=True)
# Out:
# B01002
# 4.0    0.430304
# 1.0    0.379143
# 2.0    0.104835
# 3.0    0.034545
# 5.0    0.029734
# 9.0    0.021439
# Name: proportion, dtype: float64

# %%
column_replace(df, 'B01002', 9, 0)

normaliza_coluna(df, 'B01002')

df['B01002'].value_counts(normalize=True)
# Out:
# B01002
# 4.0    0.430304
# 1.0    0.379143
# 2.0    0.104835
# 3.0    0.034545
# 5.0    0.029734
# 0.0    0.021439
# Name: proportion, dtype: float64

# %%
del df['B01021A']

# %% [markdown]
# ## Quando terminar o Ensino Fundamental, você pretende? ![image.png](data:image/png;base64,...)

# %%
df['B01026A1'].value_counts(normalize=True)
# Out:
# B01026A1
# -1.0    0.445190
#  3.0    0.285356
#  1.0    0.192453
#  5.0    0.039652
#  4.0    0.020770
#  2.0    0.016262
#  9.0    0.000316
# Name: proportion, dtype: float64

# %%
del df['B01026A1']

# %% [markdown]
# ## Quando terminar o Ensino Médio, você pretende? ![image.png](data:image/png;base64,...)

# %%
df['B01026A2'].value_counts(normalize=True)
# Out:
# B01026A2
#  3.0    0.657984
#  1.0    0.145838
#  5.0    0.070466
#  2.0    0.063282
#  4.0    0.061578
#  9.0    0.000518
# -1.0    0.000335
# Name: proportion, dtype: float64

# %%
column_replace(df, 'B01026A2', 9, np.nan)
column_replace(df, 'B01026A2', -1, np.nan)

normaliza_coluna(df, 'B01026A2')

df['B01026A2'].value_counts(normalize=True)
# Out:
# B01026A2
# 2.0    0.658545
# 0.0    0.145962
# 4.0    0.070526
# 1.0    0.063336
# 3.0    0.061630
# Name: proportion, dtype: float64

# %% [markdown]
# ## Você mora com sua mãe? ![image.png](data:image/png;base64,...)

# %%
df['B01006'].value_counts(normalize=True)
# Out:
# B01006
# 1.0    0.888796
# 2.0    0.110813
# 9.0    0.000391
# Name: proportion, dtype: float64

# %%
column_replace(df, 'B01006', 9, np.nan)

column_replace(df, 'B01006', 2, 0)


df['B01006'].value_counts(normalize=True)
# Out:
# B01006
# 1.0    0.889144
# 0.0    0.110856
# Name: proportion, dtype: float64

# %% [markdown]
# ## Você mora com seu pai? ![image.png](data:image/png;base64,...)

# %%
df['B01007'].value_counts(normalize=True)
# Out:
# B01007
# 1.0    0.633439
# 2.0    0.365892
# 9.0    0.000669
# Name: proportion, dtype: float64

# %%
column_replace(df, 'B01007', 9, np.nan)

column_replace(df, 'B01007', 2, 0)

df['B01007'].value_counts(normalize=True)
# Out:
# B01007
# 1.0    0.633863
# 0.0    0.366137
# Name: proportion, dtype: float64

# %% [markdown]
# ## CONTANDO COM VOCÊ, quantas pessoas moram na sua casa ou apartamento? ![image.png](data:image/png;base64,...)

# %%
df['B01010A'].value_counts(normalize=True)
# Out:
# B01010A
# 4.0     0.355273
# 3.0     0.236702
# 5.0     0.188066
# 6.0     0.075485
# 2.0     0.070157
# 7.0     0.034690
# 8.0     0.017885
# 9.0     0.010682
# 10.0    0.008384
# 1.0     0.002058
# 99.0    0.000619
# Name: proportion, dtype: float64

# %%
column_replace(df, 'B01010A', 99, np.nan)

column_replace(df, 'B01010A', 8, 7)
column_replace(df, 'B01010A', 9, 7)
column_replace(df, 'B01010A', 10, 7)


df['B01010A'].value_counts(normalize=True)
# Out:
# B01010A
# 4.0    0.355493
# 3.0    0.236848
# 5.0    0.188182
# 6.0    0.075532
# 7.0    0.071685
# 2.0    0.070200
# 1.0    0.002059
# Name: proportion, dtype: float64

# %%
column_replace(df, 'B01010A', 1, 0)
column_replace(df, 'B01010A', 2, 0)

column_replace(df, 'B01010A', 3, 1)
column_replace(df, 'B01010A', 4, 2)
column_replace(df, 'B01010A', 5, 3)
column_replace(df, 'B01010A', 6, 4)
column_replace(df, 'B01010A', 7, 5)

df['B01010A'].value_counts(normalize=True)
# Out:
# B01010A
# 2.0    0.355493
# 1.0    0.236848
# 3.0    0.188182
# 4.0    0.075532
# 0.0    0.072260
# 5.0    0.071685
# Name: proportion, dtype: float64

# %% [markdown]
# ## Você tem celular? ![image.png](data:image/png;base64,...)

# %%
df['B01014'].value_counts(normalize=True)
# Out:
# B01014
# 1.0    0.867880
# 2.0    0.131918
# 9.0    0.000202
# Name: proportion, dtype: float64

# %%
column_replace(df, 'B01014', 9, np.nan)

column_replace(df, 'B01014', 2, 0)

df['B01014'].value_counts(normalize=True)
# Out:
# B01014
# 1.0    0.868056
# 0.0    0.131944
# Name: proportion, dtype: float64

# %% [markdown]
# ## Na sua casa tem computador ou notebook? ![image.png](data:image/png;base64,...)

# %%
df['B01015B'].value_counts(normalize=True)
# Out:
# B01015B
# 1.0    0.674411
# 2.0    0.325274
# 9.0    0.000316
# Name: proportion, dtype: float64

# %%
column_replace(df, 'B01015B', 9, np.nan)

column_replace(df, 'B01015B', 2, 0)

df['B01015B'].value_counts(normalize=True)
# Out:
# B01015B
# 1.0    0.674624
# 0.0    0.325376
# Name: proportion, dtype: float64

# %% [markdown]
# ## Você tem acesso à internet em sua casa? ![image.png](data:image/png;base64,...)

# %%
df['B01016'].value_counts(normalize=True)
# Out:
# B01016
# 1.0    0.907444
# 2.0    0.092291
# 9.0    0.000265
# Name: proportion, dtype: float64

# %%
column_replace(df, 'B01016', 9, np.nan)

column_replace(df, 'B01016', 2, 0)

df['B01016'].value_counts(normalize=True)
# Out:
# B01016
# 1.0    0.907685
# 0.0    0.092315
# Name: proportion, dtype: float64

# %% [markdown]
# ## Alguém que mora na sua casa tem carro? ![image.png](data:image/png;base64,...)

# %%
df['B01017'].value_counts(normalize=True)
# Out:
# B01017
# 1.0    0.662309
# 2.0    0.337363
# 9.0    0.000328
# Name: proportion, dtype: float64

# %%
column_replace(df, 'B01017', 9, np.nan)

column_replace(df, 'B01017', 2, 0)

df['B01017'].value_counts(normalize=True)
# Out:
# B01017
# 1.0    0.662526
# 0.0    0.337474
# Name: proportion, dtype: float64

# %% [markdown]
# ## Alguém que mora na sua casa tem motocicleta/moto? ![image.png](data:image/png;base64,...)

# %%
df['B01018A'].value_counts(normalize=True)
# Out:
# B01018A
# 2.0    0.625642
# 1.0    0.374036
# 9.0    0.000322
# Name: proportion, dtype: float64

# %%
column_replace(df, 'B01018A', 9, np.nan)

column_replace(df, 'B01018A', 2, 0)

df['B01018A'].value_counts(normalize=True)
# Out:
# B01018A
# 0.0    0.625844
# 1.0    0.374156
# Name: proportion, dtype: float64

# %% [markdown]
# ## Quantos banheiros completos, com vaso sanitário e chuveiro, têm dentro da sua casa? ![image.png](data:image/png;base64,...)

# %%
df['B01019A'].value_counts(normalize=True)
# Out:
# B01019A
# 2.0    0.454294
# 3.0    0.327944
# 4.0    0.125611
# 5.0    0.074955
# 1.0    0.016666
# 9.0    0.000530
# Name: proportion, dtype: float64

# %%
column_replace(df, 'B01019A', 9, np.nan)

normaliza_coluna(df, 'B01019A')

df['B01019A'].value_counts(normalize=True)
# Out:
# B01019A
# 1.0    0.454535
# 2.0    0.328118
# 3.0    0.125677
# 4.0    0.074995
# 0.0    0.016675
# Name: proportion, dtype: float64

# %% [markdown]
# ## Tem empregado(a) doméstico(a) recebendo dinheiro para fazer o trabalho em sua casa, três ou mais dias por semana? ![image.png](data:image/png;base64,...)

# %%
df['B01020A'].value_counts(normalize=True)
# Out:
# B01020A
# 2.0    0.822957
# 1.0    0.176210
# 9.0    0.000833
# Name: proportion, dtype: float64

# %%
column_replace(df, 'B01020A', 9, np.nan)

column_replace(df, 'B01020A', 2, 0)

df['B01020A'].value_counts(normalize=True)
# Out:
# B01020A
# 0.0    0.823643
# 1.0    0.176357
# Name: proportion, dtype: float64

# %% [markdown]
# ## Qual nível de ensino (grau) sua MÃE estudou ou estuda? ![image.png](data:image/png;base64,...)

# %%
df['B01008B'].value_counts(normalize=True)
# Out:
# B01008B
# 7.0    0.319990
# 5.0    0.183577
# 8.0    0.173015
# 2.0    0.116583
# 6.0    0.071849
# 4.0    0.059557
# 3.0    0.045372
# 1.0    0.028226
# 9.0    0.001831
# Name: proportion, dtype: float64

# %%
column_replace(df, 'B01008B', 9, np.nan)

normaliza_coluna(df, 'B01008B')

df['B01008B'].value_counts(normalize=True)
# Out:
# B01008B
# 6.0    0.320577
# 4.0    0.183914
# 7.0    0.173333
# 1.0    0.116797
# 5.0    0.071981
# 3.0    0.059667
# 2.0    0.045455
# 0.0    0.028277
# Name: proportion, dtype: float64

# %% [markdown]
# # VARIÁVEIS CADASTRAIS

# %% [markdown]
# ## Região geográfica ![image.png](data:image/png;base64,...)

# %%
df['REGIAO'].value_counts(normalize=True)
# Out:
# REGIAO
# 2    0.350835
# 1    0.223667
# 3    0.179502
# 5    0.138283
# 4    0.107712
# Name: proportion, dtype: float64

# %%
contagem = df['REGIAO'].value_counts()

contagem.plot(
    kind='bar',
    figsize=(8, 5)
)

plt.title('Quantidade por Região')
plt.xlabel('Região')
plt.ylabel('Quantidade')
plt.xticks(rotation=15)

plt.show()

# %% [markdown]
# ## Unidade da Federação ![image.png](data:image/png;base64,...)

# %%
df['UF'].value_counts(normalize=True)
# Out:
# UF
# 52    0.055044
# 31    0.048977
# 26    0.046517
# 32    0.044941
# 35    0.044583
# 21    0.042492
# 25    0.041947
# 33    0.041001
# 28    0.040844
# 42    0.039995
# 24    0.039813
# 16    0.038535
# 29    0.038407
# 41    0.038322
# 11    0.035928
# 22    0.035765
# 23    0.034322
# 17    0.033680
# 15    0.033080
# 50    0.031546
# 27    0.030728
# 51    0.030546
# 43    0.029395
# 12    0.028565
# 13    0.027249
# 14    0.026631
# 53    0.021146
# Name: proportion, dtype: float64

# %%
contagem = df['UF'].value_counts()

contagem.plot(
    kind='bar',
    figsize=(8, 5)
)

plt.title('Quantidade por Estado')
plt.xlabel('Estado')
plt.ylabel('Quantidade')
plt.xticks(rotation=15)

plt.show()

# %%
x = 0;
for i in range(11, 18):
  column_replace(df, 'UF', i, x)
  x += 1

for i in range(21, 30):
  column_replace(df, 'UF', i, x)
  x += 1

for i in range(31, 36):
  if i != 34:
    column_replace(df, 'UF', i, x)
    x += 1

for i in range(41, 44):
  column_replace(df, 'UF', i, x)
  x += 1

for i in range(50, 54):
  column_replace(df, 'UF', i, x)
  x += 1

df['UF'].value_counts(normalize=True)
# Out:
# UF
# 25    0.055044
# 16    0.048977
# 12    0.046517
# 17    0.044941
# 19    0.044583
# 7     0.042492
# 11    0.041947
# 18    0.041001
# 14    0.040844
# 21    0.039995
# 10    0.039813
# 5     0.038535
# 15    0.038407
# 20    0.038322
# 0     0.035928
# 8     0.035765
# 9     0.034322
# 6     0.033680
# 4     0.033080
# 23    0.031546
# 13    0.030728
# 24    0.030546
# 22    0.029395
# 1     0.028565
# 2     0.027249
# 3     0.026631
# 26    0.021146
# Name: proportion, dtype: float64

# %% [markdown]
# ## Município da capital ![image.png](data:image/png;base64,...)

# %%
del df['MUNICIPIO_CAP']

# %% [markdown]
# ## Indicadora de município da capital ![image.png](data:image/png;base64,...)

# %%
df['TIPO_MUNIC'].value_counts(normalize=True)
# Out:
# TIPO_MUNIC
# 1.0    0.514103
# 2.0    0.485897
# Name: proportion, dtype: float64

# %%
column_replace(df, 'TIPO_MUNIC', 2, 0)

df['TIPO_MUNIC'].value_counts(normalize=True)
# Out:
# TIPO_MUNIC
# 1.0    0.514103
# 0.0    0.485897
# Name: proportion, dtype: float64

# %%
contagem = df['TIPO_MUNIC'].value_counts()

contagem.plot(
    kind='bar',
    figsize=(8, 5)
)

plt.title('Quantidade por Estado')
plt.xlabel('Estado')
plt.ylabel('É Capital?')
plt.xticks(rotation=15)

plt.show()

# %% [markdown]
# ## Situação ![image.png](data:image/png;base64,...)

# %%
df['SITUACAO'].value_counts(normalize=True)
# Out:
# SITUACAO
# 1.0    0.94889
# 2.0    0.05111
# Name: proportion, dtype: float64

# %%
del df['SITUACAO']

# %% [markdown]
# ## Dependência administrativa ![image.png](data:image/png;base64,...)

# %%
column_replace(df, 'DEP_ADMIN', 2, 0)

df['DEP_ADMIN'].value_counts(normalize=True)
# Out:
# DEP_ADMIN
# 1.0    0.510284
# 0.0    0.489716
# Name: proportion, dtype: float64

# %%
contagem = df['DEP_ADMIN'].value_counts()

contagem.plot(
    kind='bar',
    figsize=(8, 5)
)

plt.title('Quantidade por Dependencia Administrativa')
plt.xlabel('DEP ADMIN')
plt.ylabel('Quantidade')
plt.xticks(rotation=15)

plt.show()

# %% [markdown]
# ## Esfera administrativa ![image.png](data:image/png;base64,...)

# %%
normaliza_coluna(df, 'ESFERA')

df['ESFERA'].value_counts(normalize=True)
# Out:
# ESFERA
# 3.0    0.489457
# 1.0    0.391605
# 2.0    0.108054
# 0.0    0.010884
# Name: proportion, dtype: float64

# %%
contagem = df['ESFERA'].value_counts()

contagem.plot(
    kind='bar',
    figsize=(8, 5)
)

plt.title('Quantidade por Dependencia Administrativa')
plt.xlabel('DEP ADMIN')
plt.ylabel('Quantidade')
plt.xticks(rotation=15)

plt.show()

# %%
del df['ESFERA']
del df['ESCOLA'] # ID
del df['TURMA'] # ID
del df['ALUNO'] # ID

# %% [markdown]
# ## Ano escolar ![image.png](data:image/png;base64,...)

# %%
df['ANO_TURMA'].value_counts(normalize=True)
# Out:
# ANO_TURMA
# 1.0     0.197030
# 2.0     0.182643
# 3.0     0.175282
# 4.0     0.170528
# 5.0     0.133830
# 6.0     0.125396
# 7.0     0.007860
# 9.0     0.003655
# 8.0     0.003561
# 11.0    0.000158
# 12.0    0.000057
# Name: proportion, dtype: float64

# %%
# Vou excluir, pois no questionario do ALUNO tem uma pergunta muito parecidade
# E as classes que tem a mais aqui não são maiores que 1%

del df['ANO_TURMA']
del df['ESTRATO']
del df['IND_EXPANSAO']
del df['PESO_ALUNO_FREQ']
del df['PESO_INICIAL']
del df['POSEST']
del df['TOTAIS_POSEST']

# %%
df['B00004'].value_counts(normalize=True)
# Out:
# B00004
# 1.0    1.0
# Name: proportion, dtype: float64

# %%
del df['B00004']

# %% [markdown]
# # Segurança

# %% [markdown]
# ## NOS ÚLTIMOS 30 DIAS, com que frequência você usou cinto de segurança enquanto andava como passageiro(a) NO BANCO DA FRENTE de carro/automóvel, van ou táxi?
# ![image.png](data:image/png;base64,...)

# %%
df['B09006A1'].value_counts(normalize=True)
# Out:
# B09006A1
# 6.0    0.475543
# 5.0    0.158047
# 1.0    0.148357
# 4.0    0.092587
# 3.0    0.074393
# 2.0    0.045725
# 9.0    0.005347
# Name: proportion, dtype: float64

# %%
# Valor de ser Resposta muito baixo marcar com nan
column_replace(df, 'B09006A1', 9, np.nan)

# Dados bem divididos e ordem importa apenas normalizar
# Poderia juntar 3 e 4 mas considerei desnecessário

normaliza_coluna(df, 'B09006A1')

# Variavel esquisita, não sei se 1 "não andei de carro nos últimos 30 dias deveria ser considerado"

# %%
df['B09006A1'].value_counts(normalize=True)
# Out:
# B09006A1
# 5.0    0.478100
# 4.0    0.158897
# 0.0    0.149154
# 3.0    0.093085
# 2.0    0.074793
# 1.0    0.045971
# Name: proportion, dtype: float64

# %% [markdown]
# ## NOS ÚLTIMOS 30 DIAS, com que frequência você usou cinto de segurança enquanto andava como passageiro(a) NO BANCO DE TRÁS de carro/automóvel, van ou táxi?
#
# ![image.png](data:image/png;base64,...)

# %%
df['B09006A2'].value_counts(normalize=True)
# Out:
# B09006A2
# 6.0    0.317344
# 3.0    0.158268
# 5.0    0.154442
# 4.0    0.138609
# 1.0    0.121135
# 2.0    0.103654
# 9.0    0.006547
# Name: proportion, dtype: float64

# %%
# Valor de ser Resposta muito baixo marcar com nan
column_replace(df, 'B09006A2', 9, np.nan)

# Dados bem divididos  apenas normalizar
normaliza_coluna(df, 'B09006A2')

# %%
df['B09006A2'].value_counts(normalize=True)
# Out:
# B09006A2
# 5.0    0.319436
# 2.0    0.159311
# 4.0    0.155460
# 3.0    0.139523
# 0.0    0.121933
# 1.0    0.104337
# Name: proportion, dtype: float64

# %% [markdown]
# ## NOS ÚLTIMOS 30 DIAS, com que frequência você usou capacete ao andar de motocicleta/moto?
#
# ![image.png](data:image/png;base64,...)

# %%
df['B09007A'].value_counts(normalize=True)
# Out:
# B09007A
# 1.0    0.473902
# 6.0    0.341517
# 5.0    0.051496
# 4.0    0.046180
# 2.0    0.042582
# 3.0    0.038882
# 9.0    0.005442
# Name: proportion, dtype: float64

# %%
column_replace(df, 'B09007A', 9, np.nan)

# Várias de andar sem capacete são raras, vou juntar todas em uma
# Exemplo de Juntar classes
column_replace(df, 'B09007A', 1, 0) # Não ando de moto

# Já andei sem capacete

column_replace(df, 'B09007A', 5, 1)
column_replace(df, 'B09007A', 4, 1)
column_replace(df, 'B09007A', 3, 1)
column_replace(df, 'B09007A', 2, 1)

# Nunca andei sem capacete

column_replace(df, 'B09007A', 6, 2)

# 0 = Não ando de moto
# 1 = Já andei sem capacete
# 2 = Nunca andei sem capacete

# %%
df['B09007A'].value_counts(normalize=True)
# Out:
# B09007A
# 0.0    0.476495
# 2.0    0.343386
# 1.0    0.180119
# Name: proportion, dtype: float64

# %% [markdown]
# ## NOS ÚLTIMOS 30 DIAS, quantas vezes você dirigiu um veículo motorizado de transporte (carro, motocicleta/moto, voadeira, barco)?
# ![image.png](data:image/png;base64,...)

# %%
df['B09008'].value_counts(normalize=True)
# Out:
# B09008
# 1.0    0.708848
# 5.0    0.115870
# 3.0    0.067815
# 2.0    0.066672
# 4.0    0.034709
# 9.0    0.006086
# Name: proportion, dtype: float64

# %%
# Váriavel que não digiri é bem dominante, vou binarizar
column_replace(df, 'B09008', 9, np.nan)

column_replace(df, 'B09008', 3, 2)
column_replace(df, 'B09008', 4, 2)
column_replace(df, 'B09008', 5, 2)

normaliza_coluna(df, 'B09008')

# 0 = Não dirigi
# 1 = Dirigi

df['B09008'].value_counts(normalize=True)
# Out:
# B09008
# 0.0    0.713189
# 1.0    0.286811
# Name: proportion, dtype: float64

# %% [markdown]
# ## NOS ÚLTIMOS 30 DIAS, quantas vezes você andou em carro ou outro veículo motorizado dirigido por alguém que tinha consumido alguma bebida alcoólica?
#
# ![image.png](data:image/png;base64,...)

# %%
df['B09009'].value_counts(normalize=True)
# Out:
# B09009
# 1.0    0.725168
# 2.0    0.092114
# 3.0    0.085466
# 5.0    0.061899
# 4.0    0.029034
# 9.0    0.006319
# Name: proportion, dtype: float64

# %%
# Váriavel que não digiri é bem dominante, vou binarizar
column_replace(df, 'B09009', 9, np.nan)

column_replace(df, 'B09009', 3, 2)
column_replace(df, 'B09009', 4, 2)
column_replace(df, 'B09009', 5, 2)

normaliza_coluna(df, 'B09009')

# 0 = Não dirigi
# 1 = Dirigi

df['B09008'].value_counts(normalize=True)
# Out:
# B09008
# 0.0    0.713189
# 1.0    0.286811
# Name: proportion, dtype: float64

# %% [markdown]
# ## NOS ÚLTIMOS 30 DIAS, quantas vezes você andou em carro ou outro veículo motorizado dirigido por alguém que usou o celular enquanto dirigia? ![image.png](data:image/png;base64,...)

# %%
df['B09019'].value_counts(normalize=True)
# Out:
# B09019
# 1.0    0.531660
# 3.0    0.157448
# 2.0    0.140806
# 5.0    0.103989
# 4.0    0.059734
# 9.0    0.006364
# Name: proportion, dtype: float64

# %%
# Variveis bem divididas, vou deixar como esta apenas normalizar

column_replace(df, 'B09019', 9, np.nan)

normaliza_coluna(df, 'B09019')

df['B09019'].value_counts(normalize=True)
# Out:
# B09019
# 0.0    0.535065
# 2.0    0.158456
# 1.0    0.141708
# 4.0    0.104655
# 3.0    0.060117
# Name: proportion, dtype: float64

# %% [markdown]
# ## NOS ÚLTIMOS 30 DIAS, em quantos dias você deixou de ir à escola porque não se sentia seguro NO CAMINHO de casa para a escola ou da escola para casa?
#
# ![image.png](data:image/png;base64,...)

# %%
df['B09001'].value_counts(normalize=True)
# Out:
# B09001
# 1.0    0.895336
# 2.0    0.040984
# 3.0    0.022468
# 6.0    0.017392
# 4.0    0.012405
# 9.0    0.005840
# 5.0    0.005574
# Name: proportion, dtype: float64

# %%
# Uma variavel bem dominante, vou binarizar
# Exemplo de binarização

column_replace(df, 'B09001', 9, np.nan)

column_replace(df, 'B09001', 3, 2)
column_replace(df, 'B09001', 4, 2)
column_replace(df, 'B09001', 5, 2)
column_replace(df, 'B09001', 6, 2)

normaliza_coluna(df, 'B09001')

df['B09001'].value_counts(normalize=True)
# Out:
# B09001
# 0.0    0.900595
# 1.0    0.099405
# Name: proportion, dtype: float64

# %% [markdown]
# ## NOS ÚLTIMOS 30 DIAS, em quantos dias você não foi à escola porque não se sentia seguro NA ESCOLA?
# ![image.png](data:image/png;base64,...)

# %%
df['B09002'].value_counts(normalize=True)
# Out:
# B09002
# 1.0    0.899641
# 2.0    0.040220
# 3.0    0.020896
# 6.0    0.015480
# 4.0    0.011786
# 9.0    0.006332
# 5.0    0.005644
# Name: proportion, dtype: float64

# %%
# Uma variavel bem dominante, vou binarizar

column_replace(df, 'B09002', 9, np.nan)

column_replace(df, 'B09002', 3, 2)
column_replace(df, 'B09002', 4, 2)
column_replace(df, 'B09002', 5, 2)
column_replace(df, 'B09002', 6, 2)

normaliza_coluna(df, 'B09002')

df['B09002'].value_counts(normalize=True)
# Out:
# B09002
# 0.0    0.905374
# 1.0    0.094626
# Name: proportion, dtype: float64

# %% [markdown]
# ## NOS ÚLTIMOS 30 DIAS, você esteve envolvido(a) em briga com luta física? ![image.png](data:image/png;base64,...)

# %%
df['B09011A'].value_counts(normalize=True)
# Out:
# B09011A
# 2.0    0.891251
# 1.0    0.104917
# 9.0    0.003832
# Name: proportion, dtype: float64

# %%
# Variavel já é Binária só coloquei um valor não como zero

column_replace(df, 'B09011A', 9, np.nan)

column_replace(df, 'B09011A', 2, 0)

df['B09011A'].value_counts(normalize=True)
# Out:
# B09011A
# 0.0    0.89468
# 1.0    0.10532
# Name: proportion, dtype: float64

# %% [markdown]
# ## NOS ÚLTIMOS 30 DIAS, você esteve envolvido(a) em alguma briga em que alguma pessoa usou arma de fogo, como revólver ou espingarda? ![image.png](data:image/png;base64,...)

# %%
df['B09004'].value_counts(normalize=True)
# Out:
# B09004
# 2.0    0.971800
# 1.0    0.023535
# 9.0    0.004665
# Name: proportion, dtype: float64

# %%
column_replace(df, 'B09004', 9, np.nan)

column_replace(df, 'B09004', 2, 0)

df['B09004'].value_counts(normalize=True)
# Out:
# B09004
# 0.0    0.976355
# 1.0    0.023645
# Name: proportion, dtype: float64

# %%
# Varivel muito dominante, vou excluir
# Exemplo de váriavel acima de 95%

del df['B09004']

# %% [markdown]
# ## NOS ÚLTIMOS 30 DIAS, você esteve envolvido(a) em alguma briga em que alguma pessoa usou alguma outra arma como faca, canivete, peixeira, pedra, pedaço de pau ou garrafa?
#
# ![image.png](data:image/png;base64,...)

# %%
df['B09005'].value_counts(normalize=True)
# Out:
# B09005
# 2.0    0.953429
# 1.0    0.041325
# 9.0    0.005246
# Name: proportion, dtype: float64

# %%
# Varivel muito dominante, vou excluir

del df['B09005']

# %% [markdown]
# ## NOS ÚLTIMOS 12 MESES, você sofreu algum acidente ou agressão?
# ![image.png](data:image/png;base64,...)

# %%
df['B09012A1'].value_counts(normalize=True)
# Out:
# B09012A1
# 2.0    0.786985
# 1.0    0.208994
# 9.0    0.004021
# Name: proportion, dtype: float64

# %%
column_replace(df, 'B09012A1', 9, np.nan)

column_replace(df, 'B09012A1', 2, 0)

df['B09012A1'].value_counts(normalize=True)
# Out:
# B09012A1
# 0.0    0.790163
# 1.0    0.209837
# Name: proportion, dtype: float64

# %% [markdown]
# ## Algum desse(s) acidente(s) ou agressão(ões) que você sofreu o(a) impediu de realizar atividades habituais (ir para a escola, trabalhar, realizar afazeres domésticos etc.)? ![image.png](data:image/png;base64,...)

# %%
df['B09012A2'].value_counts(normalize=True)
# Out:
# B09012A2
# -1.0    0.791006
#  2.0    0.150232
#  1.0    0.058276
#  9.0    0.000486
# Name: proportion, dtype: float64

# %%
column_replace(df, 'B09012A2', 9, np.nan)

column_replace(df, 'B09012A2', 2, 0)
column_replace(df, 'B09012A2', -1, 0)


df['B09012A2'].value_counts(normalize=True)

# < 95%, então fica
# Out:
# B09012A2
# 0.0    0.941696
# 1.0    0.058304
# Name: proportion, dtype: float64

# %% [markdown]
# ## Você teve que procurar algum serviço de saúde (Pronto-socorro, emergência ou UPA, hospital, farmácia) em razão deste acidente ou agressão? ![image.png](data:image/png;base64,...)

# %%
df['B09012A3'].value_counts(normalize=True)
# Out:
# B09012A3
# -1.0    0.791006
#  2.0    0.152896
#  1.0    0.055586
#  9.0    0.000511
# Name: proportion, dtype: float64

# %%
column_replace(df, 'B09012A3', 9, np.nan)

column_replace(df, 'B09012A3', 2, 0)
column_replace(df, 'B09012A3', -1, 0)


df['B09012A3'].value_counts(normalize=True)
# Out:
# B09012A3
# 0.0    0.944385
# 1.0    0.055615
# Name: proportion, dtype: float64

# %% [markdown]
# ## Qual foi o ferimento ou a lesão MAIS GRAVE que você sofreu nesse acidente ou agressão? ![image.png](data:image/png;base64,...)

# %%
df['B09013B'].value_counts(normalize=True)
# Out:
# B09013B
# -1.0    0.791006
#  6.0    0.099759
#  2.0    0.047796
#  1.0    0.025751
#  5.0    0.016193
#  3.0    0.015057
#  9.0    0.002936
#  4.0    0.001503
# Name: proportion, dtype: float64

# %%
column_replace(df, 'B09013B', -1, 0)
column_replace(df, 'B09013B', 9, np.nan)
column_replace(df, 'B09013B', 6, 4)
df['B09013B'].value_counts(normalize=True)
# Out:
# B09013B
# 0.0    0.793335
# 4.0    0.101559
# 2.0    0.047937
# 1.0    0.025827
# 5.0    0.016241
# 3.0    0.015101
# Name: proportion, dtype: float64

# %% [markdown]
# ## Qual foi a PRINCIPAL CAUSA do ferimento ou da lesão mais grave que aconteceu com você? ![image.png](data:image/png;base64,...)

# %%
df['B09014B'].value_counts(normalize=True)
# Out:
# B09014B
# -1.0    0.791006
#  5.0    0.057007
#  6.0    0.043636
#  3.0    0.041275
#  1.0    0.027645
#  2.0    0.026628
#  4.0    0.011363
#  9.0    0.001439
# Name: proportion, dtype: float64

# %%
column_replace(df, 'B09014B', -1, 0)
column_replace(df, 'B09014B', 9, np.nan)
df['B09014B'].value_counts(normalize=True)
# Out:
# B09014B
# 0.0    0.792147
# 5.0    0.057089
# 6.0    0.043699
# 3.0    0.041334
# 1.0    0.027685
# 2.0    0.026667
# 4.0    0.011380
# Name: proportion, dtype: float64

# %% [markdown]
# ## NOS ÚLTIMOS 12 MESES, quantas vezes você foi agredido(a) fisicamente por sua mãe, pai ou responsável? ![image.png](data:image/png;base64,...)

# %%
df['B09003A'].value_counts(normalize=True)
# Out:
# B09003A
# 1.0    0.773728
# 2.0    0.111198
# 3.0    0.072354
# 4.0    0.036281
# 9.0    0.006439
# Name: proportion, dtype: float64

# %%
# Tem uma classe dominante mas a diferença entre as não dominates não é tão grande
# Vou deixar como esta e apenas normalizar

column_replace(df, 'B09003A', 9, np.nan)

normaliza_coluna(df, 'B09003A')

df['B09003A'].value_counts(normalize=True)
# Out:
# B09003A
# 0.0    0.778742
# 1.0    0.111919
# 2.0    0.072823
# 3.0    0.036516
# Name: proportion, dtype: float64

# %% [markdown]
# ## NOS ÚLTIMOS 12 MESES, quantas vezes você foi agredido(a) fisicamente por OUTRA PESSOA que não seja sua mãe, pai ou responsável? ![image.png](data:image/png;base64,...)

# %%
df['B09010A1'].value_counts(normalize=True)
# Out:
# B09010A1
# 1.0    0.845949
# 2.0    0.084885
# 3.0    0.042196
# 4.0    0.020252
# 9.0    0.006717
# Name: proportion, dtype: float64

# %%
# Vou binarizar classe bominante acima de 80% e classe minoritárias com menos de 10%

column_replace(df, 'B09010A1', 9, np.nan)

column_replace(df, 'B09010A1', 3, 2)
column_replace(df, 'B09010A1', 4, 2)

normaliza_coluna(df, 'B09010A1')

df['B09010A1'].value_counts(normalize=True)
# Out:
# B09010A1
# 0.0    0.85167
# 1.0    0.14833
# Name: proportion, dtype: float64

# %% [markdown]
# ## Quem o(a) agrediu fisicamente? (Sem contar sua mãe, pai ou responsável) - Namorado(a), ex-namorado(a), ficante, crush ![image.png](data:image/png;base64,...)

# %%
df['B09010A201'].value_counts(normalize=True)
# Out:
# B09010A201
# -1.0    0.852666
#  0.0    0.130466
#  1.0    0.014709
#  9.0    0.002159
# Name: proportion, dtype: float64

# %%
del df['B09010A201']

# %% [markdown]
# ## Quem o(a) agrediu fisicamente? (Sem contar sua mãe, pai ou responsável) - Amigo(a) ![image.png](data:image/png;base64,...)

# %%
df['B09010A202'].value_counts(normalize=True)
# Out:
# B09010A202
# -1.0    0.852666
#  1.0    0.081154
#  0.0    0.064021
#  9.0    0.002159
# Name: proportion, dtype: float64

# %%
# Esse caso é diferente pois a maioria diz que sim
# Então vou considerar os pulo como não e binarizar

column_replace(df, 'B09010A202', 9, np.nan)

column_replace(df, 'B09010A202', -1, 0)

df['B09010A202'].value_counts(normalize=True)
# Out:
# B09010A202
# 0.0    0.91867
# 1.0    0.08133
# Name: proportion, dtype: float64

# %% [markdown]
# ## Quem o(a) agrediu fisicamente? (Sem contar sua mãe, pai ou responsável) - Outros familiares ![image.png](data:image/png;base64,...)

# %%
df['B09010A203'].value_counts(normalize=True)
# Out:
# B09010A203
# -1.0    0.852666
#  0.0    0.120428
#  1.0    0.024747
#  9.0    0.002159
# Name: proportion, dtype: float64

# %%
del df['B09010A203']

# %% [markdown]
# ## Quem o(a) agrediu fisicamente? (Sem contar sua mãe, pai ou responsável) - Policial ![image.png](data:image/png;base64,...)

# %%
df['B09010A204'].value_counts(normalize=True)
# Out:
# B09010A204
# -1.0    0.852666
#  0.0    0.138584
#  1.0    0.006591
#  9.0    0.002159
# Name: proportion, dtype: float64

# %%
del df['B09010A204']

# %% [markdown]
# ## Quem o(a) agrediu fisicamente? (Sem contar sua mãe, pai ou responsável) - Profissionais da sua escola (professor, diretor, inspetor, etc.) ![image.png](data:image/png;base64,...)

# %%
df['B09010A205'].value_counts(normalize=True)
# Out:
# B09010A205
# -1.0    0.852666
#  0.0    0.143350
#  9.0    0.002159
#  1.0    0.001824
# Name: proportion, dtype: float64

# %%
del df['B09010A205']

# %% [markdown]
# ## Quem o(a) agrediu fisicamente? (Sem contar sua mãe, pai ou responsável) - Desconhecido(a) ![image.png](data:image/png;base64,...)

# %%
df['B09010A206'].value_counts(normalize=True)
# Out:
# B09010A206
# -1.0    0.852666
#  0.0    0.131267
#  1.0    0.013908
#  9.0    0.002159
# Name: proportion, dtype: float64

# %%
del df['B09010A206']

# %% [markdown]
# ## Quem o(a) agrediu fisicamente? (Sem contar sua mãe, pai ou responsável) - Outro ![image.png](data:image/png;base64,...)

# %%
df['B09010A207'].value_counts(normalize=True)
# Out:
# B09010A207
# -1.0    0.852666
#  0.0    0.122940
#  1.0    0.022235
#  9.0    0.002159
# Name: proportion, dtype: float64

# %%
del df['B09010A207']

# %% [markdown]
# ## Alguma vez na vida alguém o(a) tocou, manipulou, beijou ou expôs partes do corpo contra a sua vontade? ![image.png](data:image/png;base64,...)

# %%
df['B09016A1'].value_counts(normalize=True)
# Out:
# B09016A1
#  2.0    0.701323
# -1.0    0.161646
#  1.0    0.131513
#  9.0    0.005518
# Name: proportion, dtype: float64

# %%
# Aqui existe uma classe dominante

column_replace(df, 'B09016A1', 9, np.nan)
column_replace(df, 'B09016A1', -1, np.nan)
column_replace(df, 'B09016A1', 2, 0)


df['B09016A1'].value_counts(normalize=True)
# Out:
# B09016A1
# 0.0    0.84209
# 1.0    0.15791
# Name: proportion, dtype: float64

# %% [markdown]
# ## Quem fez isso? - Namorado(a), ex-namorado(a), ficante, crush ![image.png](data:image/png;base64,...)

# %%
df['B09017A101'].value_counts(normalize=True)
# Out:
# B09017A101
# -1.0    0.868487
#  0.0    0.094052
#  1.0    0.036641
#  9.0    0.000821
# Name: proportion, dtype: float64

# %%
del df['B09017A101']

# %% [markdown]
# ## Quem fez isso? - Amigo(a) ![image.png](data:image/png;base64,...)

# %%
df['B09017A102'].value_counts(normalize=True)
# Out:
# B09017A102
# -1.0    0.868487
#  0.0    0.095838
#  1.0    0.034854
#  9.0    0.000821
# Name: proportion, dtype: float64

# %%
del df['B09017A102']

# %% [markdown]
# ## Quem fez isso? - Pai/mãe/padrasto/madrasta ![image.png](data:image/png;base64,...)

# %%
df['B09017A103'].value_counts(normalize=True)
# Out:
# B09017A103
# -1.0    0.868487
#  0.0    0.123382
#  1.0    0.007311
#  9.0    0.000821
# Name: proportion, dtype: float64

# %%
del df['B09017A103']

# %% [markdown]
# ## Quem fez isso? - Outros familiares ![image.png](data:image/png;base64,...)

# %%
df['B09017A104'].value_counts(normalize=True)
# Out:
# B09017A104
# -1.0    0.868487
#  0.0    0.109020
#  1.0    0.021673
#  9.0    0.000821
# Name: proportion, dtype: float64

# %%
del df['B09017A104']

# %% [markdown]
# ## Quem fez isso? - Desconhecido(a) ![image.png](data:image/png;base64,...)

# %%
df['B09017A105'].value_counts(normalize=True)
# Out:
# B09017A105
# -1.0    0.868487
#  0.0    0.101640
#  1.0    0.029053
#  9.0    0.000821
# Name: proportion, dtype: float64

# %%
del df['B09017A105']

# %% [markdown]
# ## Quem fez isso? - Outro

# %%
df['B09017A106'].value_counts(normalize=True)
# Out:
# B09017A106
# -1.0    0.868487
#  0.0    0.111040
#  1.0    0.019653
#  9.0    0.000821
# Name: proportion, dtype: float64

# %%
del df['B09017A106']

# %% [markdown]
# ## Alguma vez na vida alguém ameaçou, intimidou ou obrigou a ter relações sexuais ou qualquer outro ato sexual contra a sua vontade? ![image.png](data:image/png;base64,...)

# %%
df['B09016A2'].value_counts(normalize=True)
# Out:
# B09016A2
#  2.0    0.780047
# -1.0    0.161646
#  1.0    0.052588
#  9.0    0.005720
# Name: proportion, dtype: float64

# %%
column_replace(df, 'B09016A2', 9, np.nan)

column_replace(df, 'B09016A2', -1, np.nan)
column_replace(df, 'B09016A2', 2, 0)

df['B09016A2'].value_counts(normalize=True)

# Verificar se excluimos essa váriavel
# Out:
# B09016A2
# 0.0    0.936842
# 1.0    0.063158
# Name: proportion, dtype: float64

# %% [markdown]
# ## Quem fez isso? - Namorado(a), ex-namorado(a), ficante, crush ![image.png](data:image/png;base64,...)

# %%
df['B09017A201'].value_counts(normalize=True)
# Out:
# B09017A201
# -1.0    0.947412
#  0.0    0.038838
#  1.0    0.013302
#  9.0    0.000448
# Name: proportion, dtype: float64

# %%
del df['B09017A201']

# %% [markdown]
# ## Quem fez isso? - Amigo(a) ![image.png](data:image/png;base64,...)

# %%
df['B09017A202'].value_counts(normalize=True)
# Out:
# B09017A202
# -1.0    0.947412
#  0.0    0.042689
#  1.0    0.009451
#  9.0    0.000448
# Name: proportion, dtype: float64

# %%
del df['B09017A202']

# %% [markdown]
# ## Quem fez isso? - Pai/mãe/padrasto/madrasta ![image.png](data:image/png;base64,...)

# %%
df['B09017A203'].value_counts(normalize=True)
# Out:
# B09017A203
# -1.0    0.947412
#  0.0    0.047556
#  1.0    0.004583
#  9.0    0.000448
# Name: proportion, dtype: float64

# %%
del df['B09017A203']

# %% [markdown]
# ## Quem fez isso? - Outros familiares
#
# ![image.png](data:image/png;base64,...)

# %%
df['B09017A204'].value_counts(normalize=True)
# Out:
# B09017A204
# -1.0    0.947412
#  0.0    0.040151
#  1.0    0.011988
#  9.0    0.000448
# Name: proportion, dtype: float64

# %%
del df['B09017A204']

# %% [markdown]
# ## Quem fez isso? - Desconhecido(a) ![image.png](data:image/png;base64,...)

# %%
df['B09017A205'].value_counts(normalize=True)
# Out:
# B09017A205
# -1.0    0.947412
#  0.0    0.041515
#  1.0    0.010625
#  9.0    0.000448
# Name: proportion, dtype: float64

# %%
del df['B09017A205']

# %% [markdown]
# ## Quem fez isso? - Outro ![image.png](data:image/png;base64,...)

# %%
df['B09017A206'].value_counts(normalize=True)
# Out:
# B09017A206
# -1.0    0.947412
#  0.0    0.043819
#  1.0    0.008321
#  9.0    0.000448
# Name: proportion, dtype: float64

# %%
del df['B09017A206']

# %% [markdown]
# ## Que idade você tinha quando alguém ameaçou, intimidou ou obrigou a ter relações sexuais ou qualquer outro ato sexual contra a sua vontade pela primeira vez? ![image.png](data:image/png;base64,...)

# %%
df['B09018'].value_counts(normalize=True)
# Out:
# B09018
# -1.0     0.947412
#  9.0     0.016483
#  13.0    0.006572
#  14.0    0.006477
#  15.0    0.005246
#  12.0    0.004785
#  10.0    0.003845
#  11.0    0.003365
#  16.0    0.003258
#  17.0    0.001370
#  18.0    0.000625
#  99.0    0.000562
# Name: proportion, dtype: float64

# %%
#Iria virar uma variavel binária
# Então resolvi tirar pq já tem uma várivel binaria desse tema

del df['B09018']

# %% [markdown]
# # Higiene e Saúde Bucal

# %% [markdown]
# ## Com que frequência você lava as mãos antes de comer? ![image.png](data:image/png;base64,...)

# %%
df['B10004A'].value_counts(normalize=True)
# Out:
# B10004A
# 5.0    0.386662
# 4.0    0.268999
# 3.0    0.198224
# 2.0    0.116110
# 1.0    0.027746
# 9.0    0.002260
# Name: proportion, dtype: float64

# %%
column_replace(df, 'B10004A', 9, np.nan)

normaliza_coluna(df, 'B10004A')

df['B10004A'].value_counts(normalize=True)
# Out:
# B10004A
# 4.0    0.387538
# 3.0    0.269608
# 2.0    0.198673
# 1.0    0.116373
# 0.0    0.027809
# Name: proportion, dtype: float64

# %% [markdown]
# ## Com que frequência você lava as mãos após usar o banheiro ou o vaso sanitário? ![image.png](data:image/png;base64,...)

# %%
df['B10005A'].value_counts(normalize=True)
# Out:
# B10005A
# 5.0    0.681140
# 4.0    0.167643
# 3.0    0.089065
# 2.0    0.045239
# 1.0    0.014047
# 9.0    0.002866
# Name: proportion, dtype: float64

# %%
column_replace(df, 'B10005A', 9, np.nan)

normaliza_coluna(df, 'B10005A')

df['B10005A'].value_counts(normalize=True)
# Out:
# B10005A
# 4.0    0.683098
# 3.0    0.168125
# 2.0    0.089321
# 1.0    0.045369
# 0.0    0.014087
# Name: proportion, dtype: float64

# %%
column_replace(df, 'B10005A', 1, 0)
column_replace(df, 'B10005A', 2, 0)

column_replace(df, 'B10005A', 3, 1)
column_replace(df, 'B10005A', 4, 1)


# 0 = Não tem hábito
# 1 = Tem hábito

df['B10005A'].value_counts(normalize=True)
# Out:
# B10005A
# 1.0    0.851223
# 0.0    0.148777
# Name: proportion, dtype: float64

# %% [markdown]
# ## Com que frequência você usa sabão ou sabonete quando lava suas mãos? ![image.png](data:image/png;base64,...)

# %%
df['B10006A'].value_counts(normalize=True)
# Out:
# B10006A
# 5.0    0.545864
# 4.0    0.241373
# 3.0    0.136488
# 2.0    0.060435
# 1.0    0.013100
# 9.0    0.002740
# Name: proportion, dtype: float64

# %%
column_replace(df, 'B10006A', 9, np.nan)

normaliza_coluna(df, 'B10006A')

df['B10006A'].value_counts(normalize=True)
# Out:
# B10006A
# 4.0    0.547364
# 3.0    0.242036
# 2.0    0.136863
# 1.0    0.060601
# 0.0    0.013136
# Name: proportion, dtype: float64

# %% [markdown]
# ## Quantas vezes por dia você escova os dentes? ![image.png](data:image/png;base64,...)

# %%
df['B10001B'].value_counts(normalize=True)
# Out:
# B10001B
# 4.0    0.433770
# 3.0    0.269365
# 5.0    0.239378
# 2.0    0.046944
# 1.0    0.007834
# 9.0    0.002708
# Name: proportion, dtype: float64

# %%
column_replace(df, 'B10001B', 9, np.nan)

normaliza_coluna(df, 'B10001B')

df['B10001B'].value_counts(normalize=True)
# Out:
# B10001B
# 3.0    0.434948
# 2.0    0.270097
# 4.0    0.240028
# 1.0    0.047071
# 0.0    0.007856
# Name: proportion, dtype: float64

# %% [markdown]
# ## NOS ÚLTIMOS 6 MESES, você teve dor de dente que não tenha sido causada por uso de aparelho? ![image.png](data:image/png;base64,...)

# %%
df['B10002'].value_counts(normalize=True)
# Out:
# B10002
# 2.0    0.658464
# 1.0    0.175913
# 3.0    0.162416
# 9.0    0.003207
# Name: proportion, dtype: float64

# %%
column_replace(df, 'B10002', 9, np.nan)

column_replace(df, 'B10002', 3, np.nan)
column_replace(df, 'B10002', 2, 0)


df['B10002'].value_counts(normalize=True)
# Out:
# B10002
# 0.0    0.789168
# 1.0    0.210832
# Name: proportion, dtype: float64

# %% [markdown]
# ## NOS ÚLTIMOS 12 MESES, quantas vezes você foi ao dentista?  ![image.png](data:image/png;base64,...)

# %%
df['B10003'].value_counts(normalize=True)
# Out:
# B10003
# 4.0    0.378613
# 1.0    0.287938
# 3.0    0.168281
# 2.0    0.161197
# 9.0    0.003971
# Name: proportion, dtype: float64

# %%
column_replace(df, 'B10003', 9, np.nan)

normaliza_coluna(df, 'B10003')

df['B10003'].value_counts(normalize=True)
# Out:
# B10003
# 3.0    0.380122
# 0.0    0.289086
# 2.0    0.168952
# 1.0    0.161840
# Name: proportion, dtype: float64

# %% [markdown]
# # Situações em casa e na Escola

# %% [markdown]
# ## NOS ÚLTIMOS 30 DIAS, em quantos dias você faltou às aulas ou à escola sem permissão de sua mãe, pai ou responsável? ![image.png](data:image/png;base64,...)

# %%
df['B07001'].value_counts(normalize=True)
# Out:
# B07001
# 1.0    0.837142
# 2.0    0.109310
# 3.0    0.031963
# 5.0    0.010246
# 4.0    0.009034
# 9.0    0.002304
# Name: proportion, dtype: float64

# %%
column_replace(df, 'B07001', 9, np.nan)

column_replace(df, 'B07001', 4, 3)
column_replace(df, 'B07001', 5, 3)

normaliza_coluna(df, 'B07001')

df['B07001'].value_counts(normalize=True)
# Out:
# B07001
# 0.0    0.839076
# 1.0    0.109563
# 2.0    0.051361
# Name: proportion, dtype: float64

# %% [markdown]
# ## NOS ÚLTIMOS 30 DIAS, com que frequência sua mãe, pai ou responsável sabia realmente o que você estava fazendo em seu tempo livre? ![image.png](data:image/png;base64,...)

# %%
df['B07002'].value_counts(normalize=True)
# Out:
# B07002
# 5.0    0.393335
# 4.0    0.319718
# 3.0    0.138275
# 2.0    0.078282
# 1.0    0.066628
# 9.0    0.003763
# Name: proportion, dtype: float64

# %%
column_replace(df, 'B07002', 9, np.nan)

normaliza_coluna(df, 'B07002')

df['B07002'].value_counts(normalize=True)
# Out:
# B07002
# 4.0    0.394820
# 3.0    0.320926
# 2.0    0.138797
# 1.0    0.078577
# 0.0    0.066880
# Name: proportion, dtype: float64

# %% [markdown]
# ## NOS ÚLTIMOS 30 DIAS, com que frequência sua mãe, pai ou responsável entendeu seus problemas e preocupações? ![image.png](data:image/png;base64,...)

# %%
df['B07004'].value_counts(normalize=True)
# Out:
# B07004
# 4.0    0.235426
# 5.0    0.231986
# 3.0    0.215850
# 2.0    0.164619
# 1.0    0.147492
# 9.0    0.004627
# Name: proportion, dtype: float64

# %%
column_replace(df, 'B07004', 9, np.nan)

normaliza_coluna(df, 'B07004')

df['B07004'].value_counts(normalize=True)
# Out:
# B07004
# 3.0    0.236521
# 4.0    0.233064
# 2.0    0.216853
# 1.0    0.165384
# 0.0    0.148178
# Name: proportion, dtype: float64

# %% [markdown]
# ## NOS ÚLTIMOS 30 DIAS, com que frequência os colegas de sua escola trataram você bem e/ou foram prestativos com você? ![image.png](data:image/png;base64,...)

# %%
df['B07006'].value_counts(normalize=True)
# Out:
# B07006
# 4.0    0.363764
# 5.0    0.295280
# 3.0    0.193280
# 2.0    0.091135
# 1.0    0.053068
# 9.0    0.003472
# Name: proportion, dtype: float64

# %%
column_replace(df, 'B07006', 9, np.nan)

normaliza_coluna(df, 'B07006')

df['B07006'].value_counts(normalize=True)
# Out:
# B07006
# 3.0    0.365032
# 4.0    0.296309
# 2.0    0.193954
# 1.0    0.091453
# 0.0    0.053252
# Name: proportion, dtype: float64

# %% [markdown]
# ## NOS ÚLTIMOS 30 DIAS, quantas vezes algum dos seus colegas de escola o esculachou, zoou, mangou, intimidou ou caçoou tanto que você ficou magoado, incomodado, aborrecido, ofendido ou humilhado? ![image.png](data:image/png;base64,...)

# %%
df['B07007A'].value_counts(normalize=True)
# Out:
# B07007A
# 1.0    0.601672
# 3.0    0.228577
# 2.0    0.166229
# 9.0    0.003523
# Name: proportion, dtype: float64

# %%
column_replace(df, 'B07007A', 9, np.nan)

normaliza_coluna(df, 'B07007A')

df['B07007A'].value_counts(normalize=True)
# Out:
# B07007A
# 0.0    0.603799
# 2.0    0.229385
# 1.0    0.166817
# Name: proportion, dtype: float64

# %% [markdown]
# ## NNOS ÚLTIMOS 30 DIAS, qual o motivo/causa de seus colegas terem esculachado, zombado, zoado, caçoado, mangado, intimidado ou humilhado?  ![image.png](data:image/png;base64,...)

# %%
df['B07008'].value_counts(normalize=True)

# Sem resposta não são despresiveis nesse caso
# buscar forma de tratar
# Exemplo 1: Sem resposta é maioria
# Out:
# B07008
# -1.0    0.605194
#  7.0    0.254700
#  4.0    0.061262
#  3.0    0.041287
#  1.0    0.013276
#  5.0    0.009375
#  2.0    0.008415
#  6.0    0.003251
#  9.0    0.003239
# Name: proportion, dtype: float64

# %%
column_replace(df, 'B07008', 9, np.nan)

# Pulo de questionário vira uma classe
column_replace(df, 'B07008', -1, 0)

# Classes raras (<1%) vão ser juntadas a classe "outros motivos\causas"
column_replace(df, 'B07008', 5, 2)
column_replace(df, 'B07008', 7, 2)
column_replace(df, 'B07008', 6, 2)

df['B07008'].value_counts(normalize=True)
# Out:
# B07008
# 0.0    0.607161
# 2.0    0.276637
# 4.0    0.061461
# 3.0    0.041422
# 1.0    0.013319
# Name: proportion, dtype: float64

# %% [markdown]
# ## NOS ÚLTIMOS 30 DIAS, quantas vezes algum dos seus colegas de escola se recusou a falar com você, deixou você de lado sem razão ou fez com que outros colegas deixassem de falar com você? ![image.png](data:image/png;base64,...)

# %%
df['B07011'].value_counts(normalize=True)
# Out:
# B07011
# 1.0    0.719120
# 2.0    0.150680
# 3.0    0.126185
# 9.0    0.004015
# Name: proportion, dtype: float64

# %%
column_replace(df, 'B07011', 9, np.nan)

normaliza_coluna(df, 'B07011')

df['B07011'].value_counts(normalize=True)
# Out:
# B07011
# 0.0    0.722019
# 1.0    0.151287
# 2.0    0.126694
# Name: proportion, dtype: float64

# %% [markdown]
# ## NOS ÚLTIMOS 30 DIAS, quantas vezes algum dos seus colegas de escola bateu (deu socos, tapas, chutes, pontapés) em você ou o machucou fisicamente de outra forma? ![image.png](data:image/png;base64,...)

# %%
df['B07012'].value_counts(normalize=True)

## Exemplo 2
## Código Automático detectou Outliers??
## Acredito que ele falou que 2 e 3 são oultiers
## Por esse resultado vou juntar os dois (2 e 3) em um classe só
# Out:
# B07012
# 1.0    0.843411
# 2.0    0.080637
# 3.0    0.072120
# 9.0    0.003832
# Name: proportion, dtype: float64

# %%
df['B07012'].value_counts()
# Out:
# B07012
# 1.0    133598
# 2.0     12773
# 3.0     11424
# 9.0       607
# Name: count, dtype: int64

# %%
column_replace(df, 'B07012', 9, np.nan)

column_replace(df, 'B07012', 3, 2)

normaliza_coluna(df, 'B07012')

df['B07012'].value_counts(normalize=True)
# Out:
# B07012
# 0.0    0.846655
# 1.0    0.153345
# Name: proportion, dtype: float64

# %% [markdown]
# ## NOS ÚLTIMOS 30 DIAS, você se sentiu ameaçado(a), ofendido(a) ou humilhado(a) nas redes sociais ou aplicativos de celular? ![image.png](data:image/png;base64,...)

# %%
df['B07013'].value_counts(normalize=True)

## Também detectou outliers aqui
## Mas como a váriavel já é binária não tem muito o que fazer
## Exemplo 3
# Out:
# B07013
# 2.0    0.873329
# 1.0    0.123603
# 9.0    0.003068
# Name: proportion, dtype: float64

# %%
column_replace(df, 'B07013', 9, np.nan)

normaliza_coluna(df, 'B07013')

df['B07013'].value_counts(normalize=True)
# Out:
# B07013
# 1.0    0.876016
# 0.0    0.123984
# Name: proportion, dtype: float64

# %% [markdown]
# ## NOS ÚLTIMOS 30 DIAS, você esculachou, zombou, mangou, intimidou ou caçoou algum de seus colegas da escola tanto que ele ficou magoado, aborrecido, ofendido ou humilhado? ![image.png](data:image/png;base64,...)

# %%
df['B07009'].value_counts(normalize=True)
# Out:
# B07009
# 2.0    0.874995
# 1.0    0.121444
# 9.0    0.003561
# Name: proportion, dtype: float64

# %%
column_replace(df, 'B07009', 9, np.nan)

normaliza_coluna(df, 'B07009')

df['B07009'].value_counts(normalize=True)
# Out:
# B07009
# 1.0    0.878122
# 0.0    0.121878
# Name: proportion, dtype: float64

# %% [markdown]
# # Alimentação

# %% [markdown]
# ## Você costuma tomar o café da manhã? ![image.png](data:image/png;base64,...)

# %%
df['B02019A'].value_counts(normalize=True)
# Out:
# B02019A
# 1.0    0.564185
# 5.0    0.219315
# 6.0    0.095441
# 3.0    0.043005
# 2.0    0.042518
# 4.0    0.035284
# 9.0    0.000253
# Name: proportion, dtype: float64

# %%
column_replace(df, 'B02019A', 9, np.nan)

normaliza_coluna(df, 'B02019A')

df['B02019A'].value_counts(normalize=True)
# Out:
# B02019A
# 0.0    0.564327
# 4.0    0.219371
# 5.0    0.095465
# 2.0    0.043015
# 1.0    0.042529
# 3.0    0.035293
# Name: proportion, dtype: float64

# %% [markdown]
# ## Você costuma almoçar ou jantar com sua mãe, pai ou responsável? ![image.png](data:image/png;base64,...)

# %%
df['B02017A'].value_counts(normalize=True)
# Out:
# B02017A
# 1.0    0.619424
# 5.0    0.144941
# 6.0    0.067619
# 3.0    0.058876
# 2.0    0.055309
# 4.0    0.053364
# 9.0    0.000467
# Name: proportion, dtype: float64

# %%
column_replace(df, 'B02017A', 9, np.nan)

normaliza_coluna(df, 'B02017A')

df['B02017A'].value_counts(normalize=True)
# Out:
# B02017A
# 0.0    0.619714
# 4.0    0.145009
# 5.0    0.067651
# 2.0    0.058903
# 1.0    0.055334
# 3.0    0.053389
# Name: proportion, dtype: float64

# %% [markdown]
# ## Nas suas refeições, com que frequência você costuma comer fazendo alguma outra coisa (assistindo à TV, mexendo no computador ou no celular)? ![image.png](data:image/png;base64,...)

# %%
df['B02018B'].value_counts(normalize=True)
# Out:
# B02018B
# 1.0    0.462734
# 5.0    0.278248
# 4.0    0.095567
# 3.0    0.088010
# 2.0    0.074450
# 9.0    0.000991
# Name: proportion, dtype: float64

# %%
column_replace(df, 'B02018B', 9, np.nan)

normaliza_coluna(df, 'B02018B')

df['B02018B'].value_counts(normalize=True)
# Out:
# B02018B
# 0.0    0.463193
# 4.0    0.278524
# 3.0    0.095662
# 2.0    0.088098
# 1.0    0.074524
# Name: proportion, dtype: float64

# %% [markdown]
# ## ONTEM, você tomou refrigerante? ![image.png](data:image/png;base64,...)

# %%
df['B02028'].value_counts(normalize=True)
# Out:
# B02028
# 2.0    0.595049
# 1.0    0.404616
# 9.0    0.000335
# Name: proportion, dtype: float64

# %%
column_replace(df, 'B02028', 9, np.nan)

column_replace(df, 'B02028', 2, 0)

df['B02028'].value_counts(normalize=True)
# Out:
# B02028
# 0.0    0.595248
# 1.0    0.404752
# Name: proportion, dtype: float64

# %% [markdown]
# ## ONTEM, você tomou suco de fruta em caixinha ou lata? ![image.png](data:image/png;base64,...)

# %%
df['B02029'].value_counts(normalize=True)
# Out:
# B02029
# 2.0    0.749403
# 1.0    0.250003
# 9.0    0.000593
# Name: proportion, dtype: float64

# %%
column_replace(df, 'B02029', 9, np.nan)

column_replace(df, 'B02029', 2, 0)

df['B02029'].value_counts(normalize=True)
# Out:
# B02029
# 0.0    0.749848
# 1.0    0.250152
# Name: proportion, dtype: float64

# %% [markdown]
# ## ONTEM, você tomou refresco em pó? ![image.png](data:image/png;base64,...)

# %%
df['B02030'].value_counts(normalize=True)
# Out:
# B02030
# 2.0    0.819554
# 1.0    0.179657
# 9.0    0.000789
# Name: proportion, dtype: float64

# %%
column_replace(df, 'B02030', 9, np.nan)

column_replace(df, 'B02030', 2, 0)

df['B02030'].value_counts(normalize=True)
# Out:
# B02030
# 0.0    0.820201
# 1.0    0.179799
# Name: proportion, dtype: float64

# %% [markdown]
# ## ONTEM, você tomou bebida achocolatada? ![image.png](data:image/png;base64,...)

# %%
df['B02031'].value_counts(normalize=True)
# Out:
# B02031
# 2.0    0.728514
# 1.0    0.270899
# 9.0    0.000587
# Name: proportion, dtype: float64

# %%
column_replace(df, 'B02031', 9, np.nan)

column_replace(df, 'B02031', 2, 0)

df['B02031'].value_counts(normalize=True)
# Out:
# B02031
# 0.0    0.728942
# 1.0    0.271058
# Name: proportion, dtype: float64

# %% [markdown]
# ## ONTEM, você tomou iogurte com sabor? ![image.png](data:image/png;base64,...)

# %%
df['B02032'].value_counts(normalize=True)
# Out:
# B02032
# 2.0    0.833537
# 1.0    0.165800
# 9.0    0.000663
# Name: proportion, dtype: float64

# %%
column_replace(df, 'B02032', 9, np.nan)

column_replace(df, 'B02032', 2, 0)

df['B02032'].value_counts(normalize=True)
# Out:
# B02032
# 0.0    0.83409
# 1.0    0.16591
# Name: proportion, dtype: float64

# %% [markdown]
# ## ONTEM, você comeu salgadinho de pacote (chips) ou biscoito/bolacha salgado? ![image.png](data:image/png;base64,...)

# %%
df['B02033'].value_counts(normalize=True)
# Out:
# B02033
# 2.0    0.522664
# 1.0    0.476579
# 9.0    0.000758
# Name: proportion, dtype: float64

# %%
column_replace(df, 'B02033', 9, np.nan)

column_replace(df, 'B02033', 2, 0)

df['B02033'].value_counts(normalize=True)
# Out:
# B02033
# 0.0    0.52306
# 1.0    0.47694
# Name: proportion, dtype: float64

# %% [markdown]
# ## ONTEM, você comeu biscoito ou bolacha doce, biscoito recheado ou bolinho de pacote? ![image.png](data:image/png;base64,...)

# %%
df['B02034'].value_counts(normalize=True)
# Out:
# B02034
# 2.0    0.553333
# 1.0    0.445847
# 9.0    0.000821
# Name: proportion, dtype: float64

# %%
column_replace(df, 'B02034', 9, np.nan)

column_replace(df, 'B02034', 2, 0)

df['B02034'].value_counts(normalize=True)
# Out:
# B02034
# 0.0    0.553787
# 1.0    0.446213
# Name: proportion, dtype: float64

# %% [markdown]
# ## ONTEM, você comeu chocolate, sorvete, gelatina, flan ou outra sobremesa industrializada? ![image.png](data:image/png;base64,...)

# %%
df['B02035'].value_counts(normalize=True)
# Out:
# B02035
# 2.0    0.636229
# 1.0    0.362931
# 9.0    0.000840
# Name: proportion, dtype: float64

# %%
column_replace(df, 'B02035', 9, np.nan)

column_replace(df, 'B02035', 2, 0)

df['B02035'].value_counts(normalize=True)
# Out:
# B02035
# 0.0    0.636764
# 1.0    0.363236
# Name: proportion, dtype: float64

# %% [markdown]
# ## ONTEM, você comeu salsicha, linguiça, mortadela ou presunto? ![image.png](data:image/png;base64,...)

# %%
df['B02036'].value_counts(normalize=True)
# Out:
# B02036
# 2.0    0.613629
# 1.0    0.385620
# 9.0    0.000751
# Name: proportion, dtype: float64

# %%
column_replace(df, 'B02036', 9, np.nan)

column_replace(df, 'B02036', 2, 0)

df['B02036'].value_counts(normalize=True)
# Out:
# B02036
# 0.0    0.61409
# 1.0    0.38591
# Name: proportion, dtype: float64

# %% [markdown]
# ## ONTEM, você comeu pão de forma, pão de cachorro-quente ou pão de hambúrguer? ![image.png](data:image/png;base64,...)

# %%
df['B02037'].value_counts(normalize=True)
# Out:
# B02037
# 2.0    0.559778
# 1.0    0.439452
# 9.0    0.000770
# Name: proportion, dtype: float64

# %%
column_replace(df, 'B02037', 9, np.nan)

column_replace(df, 'B02037', 2, 0)

df['B02037'].value_counts(normalize=True)
# Out:
# B02037
# 0.0    0.56021
# 1.0    0.43979
# Name: proportion, dtype: float64

# %% [markdown]
# ## ONTEM, você comeu margarina? ![image.png](data:image/png;base64,...)

# %%
df['B02038'].value_counts(normalize=True)
# Out:
# B02038
# 2.0    0.605264
# 1.0    0.393941
# 9.0    0.000795
# Name: proportion, dtype: float64

# %%
column_replace(df, 'B02038', 9, np.nan)

column_replace(df, 'B02038', 2, 0)

df['B02038'].value_counts(normalize=True)
# Out:
# B02038
# 0.0    0.605746
# 1.0    0.394254
# Name: proportion, dtype: float64

# %% [markdown]
# ## ONTEM, você comeu maionese, ketchup ou outros molhos industrializados? ![image.png](data:image/png;base64,...)

# %%
df['B02039'].value_counts(normalize=True)
# Out:
# B02039
# 2.0    0.693987
# 1.0    0.305299
# 9.0    0.000713
# Name: proportion, dtype: float64

# %%
column_replace(df, 'B02039', 9, np.nan)

column_replace(df, 'B02039', 2, 0)

df['B02039'].value_counts(normalize=True)
# Out:
# B02039
# 0.0    0.694483
# 1.0    0.305517
# Name: proportion, dtype: float64

# %% [markdown]
# ## ONTEM, você comeu macarrão instantâneo (miojo), sopa de pacote, lasanha congelada ou outro prato pronto comprado congelado? ![image.png](data:image/png;base64,...)

# %%
df['B02040'].value_counts(normalize=True)
# Out:
# B02040
# 2.0    0.816726
# 1.0    0.182226
# 9.0    0.001048
# Name: proportion, dtype: float64

# %%
column_replace(df, 'B02040', 9, np.nan)

column_replace(df, 'B02040', 2, 0)

df['B02040'].value_counts(normalize=True)
# Out:
# B02040
# 0.0    0.817583
# 1.0    0.182417
# Name: proportion, dtype: float64

# %% [markdown]
# ## NOS ÚLTIMOS 7 DIAS, em quantos dias você comeu feijão? ![image.png](data:image/png;base64,...)

# %%
df['B02001'].value_counts(normalize=True)
# Out:
# B02001
# 8.0    0.370791
# 1.0    0.128319
# 4.0    0.105561
# 5.0    0.094658
# 6.0    0.092227
# 3.0    0.083048
# 2.0    0.062133
# 7.0    0.062089
# 9.0    0.001174
# Name: proportion, dtype: float64

# %%
column_replace(df, 'B02001', 9, np.nan)

normaliza_coluna(df, 'B02001')

df['B02001'].value_counts(normalize=True)
# Out:
# B02001
# 7.0    0.371227
# 0.0    0.128470
# 3.0    0.105685
# 4.0    0.094769
# 5.0    0.092336
# 2.0    0.083146
# 1.0    0.062206
# 6.0    0.062162
# Name: proportion, dtype: float64

# %% [markdown]
# ## NOS ÚLTIMOS 7 DIAS, em quantos dias você comeu pelo menos um tipo de legume ou verdura que não seja batata ou aipim (mandioca/macaxeira)? ![image.png](data:image/png;base64,...)

# %%
df['B02004B'].value_counts(normalize=True)
# Out:
# B02004B
# 1.0    0.254050
# 8.0    0.214821
# 4.0    0.121899
# 3.0    0.113029
# 2.0    0.098622
# 5.0    0.091306
# 6.0    0.070081
# 7.0    0.034766
# 9.0    0.001427
# Name: proportion, dtype: float64

# %%
column_replace(df, 'B02004B', 9, np.nan)

column_replace(df, 'B02004B', 7, 6)
column_replace(df, 'B02004B', 8, 7)

normaliza_coluna(df, 'B02004B')

df['B02004B'].value_counts(normalize=True)
# Out:
# B02004B
# 0.0    0.254413
# 6.0    0.215127
# 3.0    0.122073
# 2.0    0.113190
# 5.0    0.104997
# 1.0    0.098763
# 4.0    0.091436
# Name: proportion, dtype: float64

# %% [markdown]
# ## NOS ÚLTIMOS 7 DIAS, em quantos dias você comeu guloseimas doces, como balas, confeitos, chocolates, chicletes, bombons, pirulitos e outros? ![image.png](data:image/png;base64,...)

# %%
df['B02010A'].value_counts(normalize=True)
# Out:
# B02010A
# 8.0    0.190339
# 3.0    0.156886
# 4.0    0.153028
# 2.0    0.138502
# 1.0    0.122833
# 5.0    0.107707
# 6.0    0.085536
# 7.0    0.043705
# 9.0    0.001465
# Name: proportion, dtype: float64

# %%
column_replace(df, 'B02010A', 9, np.nan)

column_replace(df, 'B02010A', 7, 6)
column_replace(df, 'B02010A', 8, 7)

normaliza_coluna(df, 'B02010A')

df['B02010A'].value_counts(normalize=True)
# Out:
# B02010A
# 6.0    0.190618
# 2.0    0.157116
# 3.0    0.153253
# 1.0    0.138705
# 5.0    0.129430
# 0.0    0.123013
# 4.0    0.107865
# Name: proportion, dtype: float64

# %% [markdown]
# ## NOS ÚLTIMOS 7 DIAS, em quantos dias você comeu frutas frescas ou salada de frutas? ![image.png](data:image/png;base64,...)

# %%
df['B02011'].value_counts(normalize=True)
# Out:
# B02011
# 1.0    0.264618
# 8.0    0.176974
# 3.0    0.122555
# 4.0    0.120251
# 2.0    0.114677
# 5.0    0.090927
# 6.0    0.071142
# 7.0    0.037386
# 9.0    0.001471
# Name: proportion, dtype: float64

# %%
column_replace(df, 'B02011', 9, np.nan)

column_replace(df, 'B02011', 7, 6)
column_replace(df, 'B02011', 8, 7)

normaliza_coluna(df, 'B02011')

df['B02011'].value_counts(normalize=True)
# Out:
# B02011
# 0.0    0.265008
# 6.0    0.177234
# 2.0    0.122736
# 3.0    0.120428
# 1.0    0.114846
# 5.0    0.108688
# 4.0    0.091061
# Name: proportion, dtype: float64

# %% [markdown]
# ## NOS ÚLTIMOS 7 DIAS, em quantos dias você tomou refrigerante?

# %%
df['B02013'].value_counts(normalize=True)
# Out:
# B02013
# 1.0    0.268374
# 2.0    0.181582
# 3.0    0.176361
# 4.0    0.132776
# 5.0    0.081375
# 8.0    0.078092
# 6.0    0.053225
# 7.0    0.027165
# 9.0    0.001048
# Name: proportion, dtype: float64

# %%
column_replace(df, 'B02013', 9, np.nan)

column_replace(df, 'B02013', 7, 6)
column_replace(df, 'B02013', 8, 7)

normaliza_coluna(df, 'B02013')

df['B02013'].value_counts(normalize=True)
# Out:
# B02013
# 0.0    0.268656
# 1.0    0.181773
# 2.0    0.176546
# 3.0    0.132915
# 4.0    0.081461
# 5.0    0.080475
# 6.0    0.078174
# Name: proportion, dtype: float64

# %% [markdown]
# ## NOS ÚLTIMOS 7 DIAS, em quantos deles você comeu em lanchonetes, barracas de cachorro quente, pizzaria, fast food etc? ![image.png](data:image/png;base64,...)

# %%
df['B02023A'].value_counts(normalize=True)
# Out:
# B02023A
# 1.0    0.475291
# 2.0    0.221607
# 3.0    0.128490
# 4.0    0.072569
# 5.0    0.039141
# 6.0    0.025101
# 8.0    0.022607
# 7.0    0.013687
# 9.0    0.001509
# Name: proportion, dtype: float64

# %%
column_replace(df, 'B02023A', 9, np.nan)

column_replace(df, 'B02023A', 6, 5)
column_replace(df, 'B02023A', 7, 5)
column_replace(df, 'B02023A', 8, 5)

normaliza_coluna(df, 'B02023A')

df['B02023A'].value_counts(normalize=True)
# Out:
# B02023A
# 0.0    0.476009
# 1.0    0.221942
# 2.0    0.128684
# 4.0    0.100687
# 3.0    0.072678
# Name: proportion, dtype: float64

# %% [markdown]
# ## Sua escola oferece comida/merenda aos alunos da sua turma? (Não considerar comida comprada na cantina) ![image.png](data:image/png;base64,...)

# %%
df['B02021A'].value_counts(normalize=True)
# Out:
# B02021A
# 1.0    0.482974
# 2.0    0.441446
# 3.0    0.074488
# 9.0    0.001092
# Name: proportion, dtype: float64

# %%
column_replace(df, 'B02021A', 9, np.nan)
column_replace(df, 'B02021A', 3, np.nan)

column_replace(df, 'B02021A', 2, 0)

df['B02021A'].value_counts(normalize=True)
# Out:
# B02021A
# 1.0    0.522461
# 0.0    0.477539
# Name: proportion, dtype: float64

# %% [markdown]
# ## Você costuma comer a comida/merenda oferecida pela escola? (Não considerar comida comprada na cantina)  ![image.png](data:image/png;base64,...)

# %%
df['B02020B'].value_counts(normalize=True)
# Out:
# B02020B
# -1.0    0.517026
#  1.0    0.152959
#  4.0    0.130207
#  5.0    0.099500
#  2.0    0.060271
#  3.0    0.039703
#  9.0    0.000335
# Name: proportion, dtype: float64

# %%
column_replace(df, 'B02020B', 9, np.nan)
column_replace(df, 'B02020B', -1, 0)
column_replace(df, 'B02020B', 5, 0)

column_replace(df, 'B02020B', 3, 2)
column_replace(df, 'B02020B', 4, 3)

df['B02020B'].value_counts(normalize=True)
# Out:
# B02020B
# 0.0    0.616733
# 1.0    0.153010
# 3.0    0.130250
# 2.0    0.100007
# Name: proportion, dtype: float64

# %% [markdown]
# ## Você costuma comprar alimentos ou bebidas na cantina dentro da escola? (Não considerar a compra de água) ![image.png](data:image/png;base64,...)

# %%
df['B02041'].value_counts(normalize=True)
# Out:
# B02041
# 4.0    0.289245
# 5.0    0.257080
# 6.0    0.144840
# 1.0    0.121009
# 3.0    0.101299
# 2.0    0.084525
# 9.0    0.002001
# Name: proportion, dtype: float64

# %%
column_replace(df, 'B02041', 9, np.nan)

normaliza_coluna(df, 'B02041')

df['B02041'].value_counts(normalize=True)
# Out:
# B02041
# 3.0    0.289825
# 4.0    0.257596
# 5.0    0.145131
# 0.0    0.121251
# 2.0    0.101502
# 1.0    0.084695
# Name: proportion, dtype: float64

# %% [markdown]
# ## Você costuma comprar alimentos ou bebidas de vendedores de rua (camelô ou ambulante) na porta ou ao redor da escola? (Não considerar a compra de água) ![image.png](data:image/png;base64,...)

# %%
df['B02042'].value_counts(normalize=True)
# Out:
# B02042
# 4.0    0.344301
# 5.0    0.330734
# 6.0    0.177157
# 3.0    0.067291
# 2.0    0.039823
# 1.0    0.039040
# 9.0    0.001654
# Name: proportion, dtype: float64

# %%
column_replace(df, 'B02042', 9, np.nan)

column_replace(df, 'B02042', 2, 1)
column_replace(df, 'B02042', 3, 2)
column_replace(df, 'B02042', 4, 3)
column_replace(df, 'B02042', 5, 4)
column_replace(df, 'B02042', 6, 5)

normaliza_coluna(df, 'B02042')

df['B02042'].value_counts(normalize=True)
# Out:
# B02042
# 2.0    0.344872
# 3.0    0.331282
# 4.0    0.177450
# 0.0    0.078993
# 1.0    0.067402
# Name: proportion, dtype: float64

# %% [markdown]
# # Saúde Sexual e Reprodutiva

# %% [markdown]
# ## Você já teve relação sexual (transou) alguma vez? ![image.png](data:image/png;base64,...)

# %%
df['B08001'].value_counts(normalize=True)
# Out:
# B08001
#  2.0    0.551622
#  1.0    0.283065
# -1.0    0.161646
#  9.0    0.003668
# Name: proportion, dtype: float64

# %%
column_replace(df, 'B08001', 9, np.nan)
# Decidi fazer replace no -1 para np.nan
# Porque essa classe o -1 não é a maioria
# apesar de ter valor consideravél
# Não achei que fazia sentido colocar os "Pulo de questionário" junto com o 'Não' nessa pergunta
# Exemplo 4
column_replace(df, 'B08001', -1, np.nan)

normaliza_coluna(df, 'B08001')

df['B08001'].value_counts(normalize=True)
# Out:
# B08001
# 1.0    0.660873
# 0.0    0.339127
# Name: proportion, dtype: float64

# %% [markdown]
# ## Que idade você tinha quando teve relação sexual (transou) pela primeira vez? ![image.png](data:image/png;base64,...)

# %%
df['B08002'].value_counts(normalize=True)

# Exemplo 5
# Aqui como o algoritmo automatico acha que o 9 é sem resposta
# Acabou perdendo essa informação
# Out:
# B08002
# -1.0     0.716935
#  15.0    0.065296
#  14.0    0.064841
#  13.0    0.043017
#  16.0    0.038781
#  12.0    0.021748
#  17.0    0.014394
#  9.0     0.013371
#  11.0    0.009331
#  10.0    0.006900
#  18.0    0.004059
#  99.0    0.001326
# Name: proportion, dtype: float64

# %%
del df['B08002']

# %% [markdown]
# ## Você ou seu(sua) parceiro(a) usou camisinha (preservativo) NA PRIMEIRA RELAÇÃO SEXUAL? ![image.png](data:image/png;base64,...)

# %%
df['B08011A'].value_counts(normalize=True)
# Out:
# B08011A
# -1.0    0.716935
#  1.0    0.177820
#  2.0    0.104323
#  9.0    0.000922
# Name: proportion, dtype: float64

# %%
column_replace(df, 'B08011A', 9, np.nan)
column_replace(df, 'B08011A', -1, np.nan)
column_replace(df, 'B08011A', 2, 0)

df['B08011A'].value_counts(normalize=True)
# Out:
# B08011A
# 1.0    0.630247
# 0.0    0.369753
# Name: proportion, dtype: float64

# %% [markdown]
# ## NA ÚLTIMA VEZ que você teve relação sexual (transou), você ou seu(sua) parceiro(a) usou camisinha (preservativo)? ![image.png](data:image/png;base64,...)

# %%
df['B08006A'].value_counts(normalize=True)
# Out:
# B08006A
# -1.0    0.716935
#  1.0    0.167536
#  2.0    0.114184
#  9.0    0.001345
# Name: proportion, dtype: float64

# %%
column_replace(df, 'B08006A', 9, np.nan)
column_replace(df, 'B08006A', -1, np.nan)
column_replace(df, 'B08006A', 2, 0)

df['B08006A'].value_counts(normalize=True)
# Out:
# B08006A
# 1.0    0.594689
# 0.0    0.405311
# Name: proportion, dtype: float64

# %% [markdown]
# ## Nesta última vez que você teve relação sexual (transou), como você conseguiu a camisinha (preservativo)? ![image.png](data:image/png;base64,...)

# %%
df['B08014'].value_counts(normalize=True)
# Out:
# B08014
# -1.0    0.832464
#  5.0    0.071811
#  6.0    0.037051
#  1.0    0.029255
#  4.0    0.010511
#  3.0    0.010511
#  7.0    0.005562
#  2.0    0.001698
#  9.0    0.001136
# Name: proportion, dtype: float64

# %%
del df['B08014']

# %% [markdown]
# ## NA ÚLTIMA VEZ que você teve relação sexual (transou), você ou seu(sua) parceiro(a) usou algum outro método para evitar a gravidez que não seja camisinha (preservativo)? ![image.png](data:image/png;base64,...)

# %%
df['B08007'].value_counts(normalize=True)
# Out:
# B08007
# -1.0    0.716935
#  2.0    0.148653
#  1.0    0.095516
#  3.0    0.036906
#  9.0    0.001989
# Name: proportion, dtype: float64

# %%
del df['B08007']

# %% [markdown]
# ## Nesta última vez que você teve relação sexual (transou), qual outro método você ou seu(sua) parceiro(a) usou para evitar gravidez? ![image.png](data:image/png;base64,...)

# %%
df['B08012A'].value_counts(normalize=True)
# Out:
# B08012A
# -1.0     0.904484
#  1.0     0.048289
#  6.0     0.017898
#  2.0     0.009981
#  10.0    0.007153
#  9.0     0.005076
#  8.0     0.003687
#  7.0     0.001098
#  5.0     0.000859
#  99.0    0.000720
#  3.0     0.000511
#  4.0     0.000246
# Name: proportion, dtype: float64

# %%
del df['B08012A']

# %% [markdown]
# ## Alguma vez na vida, você ou sua parceira já usou pílula do dia seguinte (contracepção de emergência)? ![image.png](data:image/png;base64,...)

# %%
df['B08015'].value_counts(normalize=True)
# Out:
# B08015
# -1.0    0.716935
#  2.0    0.148445
#  1.0    0.098982
#  3.0    0.033585
#  9.0    0.002052
# Name: proportion, dtype: float64

# %%
column_replace(df, 'B08015', 9, np.nan)
column_replace(df, 'B08015', -1, np.nan)
column_replace(df, 'B08015', 3, np.nan)
column_replace(df, 'B08015', 2, 0)

df['B08015'].value_counts(normalize=True)
# Out:
# B08015
# 0.0    0.599954
# 1.0    0.400046
# Name: proportion, dtype: float64

# %% [markdown]
# ## NA ÚLTIMA VEZ que você ou sua parceira usou pílula do dia seguinte (contracepção de emergência) como conseguiu? ![image.png](data:image/png;base64,...)

# %%
df['B08016'].value_counts(normalize=True)
# Out:
# B08016
# -1.0    0.901018
#  4.0    0.071622
#  5.0    0.009223
#  1.0    0.008763
#  3.0    0.003510
#  2.0    0.003314
#  6.0    0.002172
#  9.0    0.000379
# Name: proportion, dtype: float64

# %%
del df['B08016']

# %% [markdown]
# ## Alguma vez na vida você engravidou, mesmo que a gravidez não tenha chegado ao fim? ![image.png](data:image/png;base64,...)

# %%
df['B08013A'].value_counts(normalize=True)
# Out:
# B08013A
# -1.0    0.875178
#  2.0    0.111507
#  1.0    0.010114
#  9.0    0.003201
# Name: proportion, dtype: float64

# %%
del df['B08013A']

# %% [markdown]
# ## Na escola, você já recebeu orientação sobre prevenção de gravidez? ![image.png](data:image/png;base64,...)

# %%
df['B08008A'].value_counts(normalize=True)
# Out:
# B08008A
#  1.0    0.621248
#  2.0    0.213564
# -1.0    0.161646
#  9.0    0.003542
# Name: proportion, dtype: float64

# %%
column_replace(df, 'B08008A', 9, np.nan)
column_replace(df, 'B08008A', -1, np.nan)

column_replace(df, 'B08008A', 2, 0)

df['B08008A'].value_counts(normalize=True)
# Out:
# B08008A
# 1.0    0.744177
# 0.0    0.255823
# Name: proportion, dtype: float64

# %% [markdown]
# ## Na escola, você já recebeu orientação sobre prevenção de HIV/AIDS ou outras Doenças/Infecções Sexualmente Transmissíveis? ![image.png](data:image/png;base64,...)

# %%
df['B08009A'].value_counts(normalize=True)
# Out:
# B08009A
#  1.0    0.687352
# -1.0    0.161646
#  2.0    0.147429
#  9.0    0.003573
# Name: proportion, dtype: float64

# %%
column_replace(df, 'B08009A', 9, np.nan)
column_replace(df, 'B08009A', -1, np.nan)

column_replace(df, 'B08009A', 2, 0)

df['B08009A'].value_counts(normalize=True)
# Out:
# B08009A
# 1.0    0.823392
# 0.0    0.176608
# Name: proportion, dtype: float64

# %% [markdown]
# ## Na escola, você já recebeu orientação sobre como conseguir camisinha (preservativo) gratuitamente? ![image.png](data:image/png;base64,...)

# %%
df['B08010A'].value_counts(normalize=True)
# Out:
# B08010A
#  1.0    0.532657
#  2.0    0.301827
# -1.0    0.161646
#  9.0    0.003870
# Name: proportion, dtype: float64

# %%
column_replace(df, 'B08010A', 9, np.nan)
column_replace(df, 'B08010A', -1, np.nan)

column_replace(df, 'B08010A', 2, 0)

df['B08009A'].value_counts(normalize=True)
# Out:
# B08009A
# 1.0    0.823392
# 0.0    0.176608
# Name: proportion, dtype: float64

# %% [markdown]
# # VARIÁVEIS DERIVADAS

# %% [markdown]
# ## Tempo semanal em minutos de deslocamento entre casa e escola (0 a 840)

# %%
df['TEMPODESLOC'].value_counts(normalize=True)
# Out:
# TEMPODESLOC
# 0.0      0.476433
# 50.0     0.115226
# 150.0    0.068800
# 25.0     0.026673
# 60.0     0.023182
#            ...
# 675.0    0.000006
# 580.0    0.000006
# 615.0    0.000006
# 645.0    0.000006
# 695.0    0.000006
# Name: proportion, Length: 139, dtype: float64

# %%
## DADO ESTRANHO
## QUASE A METADE DOS ALUNOS NÃO SE DESLOCA??
## VOU REMOVER

del df['TEMPODESLOC']

# %% [markdown]
# ## Tempo semanal em minutos de atividade física na aula de Educação Física (0 a 560)

# %%
df['TEMPOEDFIS'].value_counts(normalize=True)
# Out:
# TEMPOEDFIS
# 0.0       0.401794
# 45.0      0.070321
# 90.0      0.056937
# 70.0      0.052758
# 55.0      0.048402
# 35.0      0.046129
# 80.0      0.044640
# 25.0      0.037392
# 110.0     0.032462
# 15.0      0.032411
# 5.0       0.029192
# 50.0      0.023125
# 30.0      0.020309
# 160.0     0.018371
# 10.0      0.018163
# 140.0     0.010290
# 135.0     0.008908
# 75.0      0.005707
# 105.0     0.005353
# 9999.0    0.004747
# 165.0     0.003876
# 240.0     0.003655
# 180.0     0.002361
# 275.0     0.001995
# 175.0     0.001913
# 400.0     0.001913
# 210.0     0.001913
# 225.0     0.001787
# 125.0     0.001730
# 220.0     0.001616
# 20.0      0.001597
# 60.0      0.001521
# 320.0     0.001503
# 100.0     0.001414
# 350.0     0.001080
# 280.0     0.000663
# 560.0     0.000436
# 385.0     0.000246
# 480.0     0.000234
# 315.0     0.000227
# 420.0     0.000183
# 330.0     0.000177
# 245.0     0.000170
# 270.0     0.000145
# 150.0     0.000139
# 490.0     0.000095
# ...

# %%
df['TEMPOEDFIS'].describe()
# Out:
# count    158402.000000
# mean         88.037165
# std         686.710551
# min           0.000000
# 25%           0.000000
# 50%          25.000000
# 75%          70.000000
# max        9999.000000
# Name: TEMPOEDFIS, dtype: float64

# %%
df_999 = df[df['TEMPOEDFIS'] > 560]

df_999['TEMPOEDFIS']
# Out:
# 13        9999.0
# 1435      9999.0
# 1450      9999.0
# 1516      9999.0
# 1612      9999.0
#            ...
# 164730    9999.0
# 164905    9999.0
# 164983    9999.0
# 165225    9999.0
# 165269    9999.0
# Name: TEMPOEDFIS, Length: 752, dtype: float64

# %%
df['TEMPOEDFIS'].hist()
# Out:
# <Axes: >

# %%
df['TEMPOEDFIS'] = df['TEMPOEDFIS'].replace(9999, np.nan)

# %%
df['TEMPOEDFIS'].hist()
# Out:
# <Axes: >

# %%
(df['TEMPOEDFIS'].isna().mean()) * 100
# Out:
# np.float64(4.451650050001516)

# %%
df["TEMPOEDFIS"].plot.box()

plt.title("Boxplot - Atividade Física")
plt.ylabel("Minutos")
plt.show()

# %%
df["TEMPOEDFIS"].describe()
# Out:
# count    157650.000000
# mean         40.761275
# std          55.074807
# min           0.000000
# 25%           0.000000
# 50%          25.000000
# 75%          70.000000
# max         560.000000
# Name: TEMPOEDFIS, dtype: float64

# %%
from sklearn.preprocessing import RobustScaler

# Usar robustScaler por conta das váriaveis outliers

scaler = RobustScaler()

df[['TEMPOEDFIS']] = scaler.fit_transform(df[['TEMPOEDFIS']])

# %% [markdown]
# ## Tempo semanal em minutos de atividade física sem ser na aula de Educação Física (0 a 560)

# %%
df['TEMPOEXTRA'].value_counts(normalize=True)
# Out:
# TEMPOEXTRA
# 0.0       0.335930
# 560.0     0.039905
# 15.0      0.027594
# 5.0       0.025681
# 75.0      0.025202
# 400.0     0.023958
# 240.0     0.023112
# 140.0     0.023068
# 70.0      0.023036
# 45.0      0.022847
# 160.0     0.022790
# 30.0      0.022039
# 25.0      0.020259
# 105.0     0.019886
# 210.0     0.018144
# 110.0     0.017847
# 320.0     0.016932
# 50.0      0.016875
# 165.0     0.016603
# 175.0     0.015953
# 480.0     0.015701
# 80.0      0.015322
# 35.0      0.014968
# 90.0      0.014406
# 10.0      0.014249
# 275.0     0.014135
# 350.0     0.012759
# 55.0      0.011730
# 220.0     0.011345
# 135.0     0.010701
# 385.0     0.010208
# 280.0     0.009981
# 125.0     0.009665
# 490.0     0.009185
# 245.0     0.008030
# 100.0     0.007885
# 225.0     0.007475
# 180.0     0.007020
# 420.0     0.006856
# 60.0      0.006723
# 315.0     0.005795
# 330.0     0.005682
# 9999.0    0.003441
# 20.0      0.003441
# 270.0     0.002835
# 150.0     0.002803
# ...

# %%
df['TEMPOEXTRA'] = df['TEMPOEXTRA'].replace(9999, np.nan)

# %%
df['TEMPOEXTRA'].describe()
# Out:
# count    157857.000000
# mean        120.699652
# std         156.053541
# min           0.000000
# 25%           0.000000
# 50%          50.000000
# 75%         175.000000
# max         560.000000
# Name: TEMPOEXTRA, dtype: float64

# %%
df["TEMPOEXTRA"].plot.box()

plt.title("Boxplot - Atividade Física")
plt.ylabel("Minutos")
plt.show()

# %%
df['TEMPOEXTRA'].hist()
# Out:
# <Axes: >

# %%
scaler = RobustScaler()

df[['TEMPOEXTRA']] = scaler.fit_transform(df[['TEMPOEXTRA']])

# %%
df['TEMPOEXTRA'].hist()
# Out:
# <Axes: >

# %%
(df['TEMPOEXTRA'].isna().mean()) * 100
# Out:
# np.float64(4.326191702778872)

# %% [markdown]
# ## Tempo semanal em minutos de atividade física acumulada (0 a 1960)

# %%
df['TEMPOTOTAL'].value_counts(normalize=True)

## Se modelos ficarem ruins
## df["atividade_log"] = np.log1p(df["TEMPOEDFIS"]) + StandardScaler
# Out:
# TEMPOTOTAL
# 0.0       0.093256
# 50.0      0.030233
# 150.0     0.022020
# 45.0      0.018636
# 70.0      0.017386
#             ...
# 1315.0    0.000006
# 1335.0    0.000006
# 1415.0    0.000006
# 1145.0    0.000006
# 1275.0    0.000006
# Name: proportion, Length: 291, dtype: float64

# %%
df_999 = df[df['TEMPOTOTAL'] > 1960]

df_999['TEMPOTOTAL'].describe()
# Out:
# count    1702.0
# mean     9999.0
# std         0.0
# min      9999.0
# 25%      9999.0
# 50%      9999.0
# 75%      9999.0
# max      9999.0
# Name: TEMPOTOTAL, dtype: float64

# %%
df['TEMPOTOTAL'] = df['TEMPOTOTAL'].replace(9999, np.nan)

# %%
df['TEMPOTOTAL'].hist()
# Out:
# <Axes: >

# %%
df["TEMPOTOTAL"].plot.box()

plt.title("Boxplot - Atividade Física")
plt.ylabel("Minutos")
plt.show()

# %%
df_999 = df[df['TEMPOTOTAL'] > 1960]

df_999['TEMPOTOTAL'].count()
# Out:
# np.int64(0)

# %%
df.loc[df["TEMPOTOTAL"] > 1960, "TEMPOTOTAL"] = np.nan

# %%
df["TEMPOTOTAL"].plot.box()

plt.title("Boxplot - Atividade Física")
plt.ylabel("Minutos")
plt.show()

# %%
scaler = RobustScaler()

df[['TEMPOTOTAL']] = scaler.fit_transform(df[['TEMPOTOTAL']])

# %%
df['TEMPOTOTAL'].hist()
# Out:
# <Axes: >

# %%
df['TEMPOTOTAL'].value_counts()
# Out:
# TEMPOTOTAL
# -0.622642    14772
# -0.433962     4789
# -0.056604     3488
# -0.452830     2952
# -0.358491     2754
#              ...
#  4.339623        1
#  4.169811        1
#  4.415094        1
#  3.698113        1
#  4.188679        1
# Name: count, Length: 290, dtype: int64

# %%
(df['TEMPOTOTAL'].isna().mean()) * 100
# Out:
# np.float64(5.027425073487075)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 164995 entries, 0 to 165837
# Columns: 260 entries, REGIAO to E01P27A
# dtypes: float64(258), int64(2)
# memory usage: 328.5 MB

# %%
df.to_csv('Final.csv')
